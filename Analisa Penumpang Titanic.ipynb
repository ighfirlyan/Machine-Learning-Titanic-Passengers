# %% [markdown]
# Pada tugas kali ini, kita akan mencoba untuk membuat model dari data training untuk mengklasifikasikan data_uji.
#
# Kita ingin melihat dengan fitur yang dimiliki apakah penumpang tersebut akan selamat atau tidak.
#
# Algoritma yang akan kita gunakan adalah logistic regression.

# %%
#import semua package/library pada sel ini, jika butuh memasukkan package/library baru maka run ulang sel ini

import pandas as pd, numpy as np #manajemen data
from sklearn.model_selection import train_test_split as tts #pembagian dataset
from sklearn import metrics #evaluasi

import sklearn.feature_selection as fs
from sklearn.linear_model import LogisticRegression #model
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2. Data Collection

# %%
#panggil data kalian dan masukkan pada dua variabel data_mentah untuk train dan data_uji untuk data_uji

data_mentah = pd.read_csv('train.csv')
data_uji = pd.read_csv('data_uji.csv')

# %%
#tampilkan head dari data_mentah

data_mentah.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  Family_Size
# 0       3    male      1       0.0         A/5 21171    Mr            1
# 1       1  female      1       1.0          PC 17599   Mrs            1
# 2       3  female      0       1.0  STON/O2. 3101282  Miss            0
# 3       1  female      1       1.0            113803   Mrs            1
# 4       3    male      0       0.0            373450    Mr            0

# %%
#tampilkan head dari data_uji

data_uji.head()
# Out:
#     Age  Cabin Embarked     Fare  \
# 0  34.5    NaN        Q   7.8292
# 1  47.0    NaN        S   7.0000
# 2  62.0    NaN        Q   9.6875
# 3  27.0    NaN        S   8.6625
# 4  22.0    NaN        S  12.2875
#
#                                            Name  Parch  PassengerId  Pclass  \
# 0                              Kelly, Mr. James      0          892       3
# 1              Wilkes, Mrs. James (Ellen Needs)      0          893       3
# 2                     Myles, Mr. Thomas Francis      0          894       2
# 3                              Wirz, Mr. Albert      0          895       3
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1          896       3
#
#       Sex  SibSp  Survived   Ticket Title  Family_Size
# 0    male      0       NaN   330911    Mr            0
# 1  female      1       NaN   363272   Mrs            1
# 2    male      0       NaN   240276    Mr            0
# 3    male      0       NaN   315154    Mr            0
# 4  female      1       NaN  3101298   Mrs            2

# %% [markdown]
# 3. Data Preparation
#
# Pada bagian ini kita akan memperbaiki nan value

# %%
#Check detail dan nilai NaN pada data_mentah. gunakan print untuk Nilai NaN

print(data_mentah.isna().sum())
data_mentah.describe()
# Out:
# Age              0
# Cabin          687
# Embarked         0
# Fare             0
# Name             0
# Parch            0
# PassengerId      0
# Pclass           0
# Sex              0
# SibSp            0
# Survived         0
# Ticket           0
# Title            0
# Family_Size      0
# dtype: int64
#               Age        Fare       Parch  PassengerId      Pclass  \
# count  891.000000  891.000000  891.000000   891.000000  891.000000
# mean    29.445196   32.204208    0.381594   446.000000    2.308642
# std     13.244896   49.693429    0.806057   257.353842    0.836071
# min      0.420000    0.000000    0.000000     1.000000    1.000000
# 25%     22.000000    7.910400    0.000000   223.500000    2.000000
# 50%     30.000000   14.454200    0.000000   446.000000    3.000000
# 75%     35.500000   31.000000    0.000000   668.500000    3.000000
# max     80.000000  512.329200    6.000000   891.000000    3.000000
#
#             SibSp    Survived  Family_Size
# count  891.000000  891.000000   891.000000
# mean     0.523008    0.383838     0.904602
# std      1.102743    0.486592     1.613459
# min      0.000000    0.000000     0.000000
# 25%      0.000000    0.000000     0.000000
# 50%      0.000000    0.000000     0.000000
# 75%      1.000000    1.000000     1.000000
# max      8.000000    1.000000    10.000000

# %%
#Check detail dan nilai NaN pada data_uji. gunakan print untuk Nilai NaN

print(data_uji.isna().sum())
data_uji.describe()
# Out:
# Age             0
# Cabin          10
# Embarked        0
# Fare            0
# Name            0
# Parch           0
# PassengerId     0
# Pclass          0
# Sex             0
# SibSp           0
# Survived       10
# Ticket          0
# Title           0
# Family_Size     0
# dtype: int64
#              Age  Cabin       Fare      Parch  PassengerId     Pclass  \
# count  10.000000    0.0  10.000000  10.000000     10.00000  10.000000
# mean   30.150000    NaN  12.270010   0.200000    896.50000   2.800000
# std    14.541225    NaN   7.777627   0.421637      3.02765   0.421637
# min    14.000000    NaN   7.000000   0.000000    892.00000   2.000000
# 25%    21.250000    NaN   7.679200   0.000000    894.25000   3.000000
# 50%    26.500000    NaN   8.943750   0.000000    896.50000   3.000000
# 75%    33.375000    NaN  11.637500   0.000000    898.75000   3.000000
# max    62.000000    NaN  29.000000   1.000000    901.00000   3.000000
#
#            SibSp  Survived  Family_Size
# count  10.000000       0.0    10.000000
# mean    0.500000       NaN     0.700000
# std     0.707107       NaN     0.948683
# min     0.000000       NaN     0.000000
# 25%     0.000000       NaN     0.000000
# 50%     0.000000       NaN     0.000000
# 75%     1.000000       NaN     1.750000
# max     2.000000       NaN     2.000000

# %% [markdown]
# Terlihat untuk data cabin memiliki banyak nilai NaN. Jadi akan kita drop data tersebut. Name, Ticket, Title juga akan kita drop karena memiliki banyak nilai unik dan berbentuk string.

# %%
#drop kolom yang tidak dibutuhkan dari kedua dataframe

new_data_mentah = data_mentah.drop(['Name','Cabin','Ticket','Title' ], axis=1)
new_data_uji = data_uji.drop(['Name','Cabin','Ticket','Title' ], axis=1)

# %%
#tampilkan head mentah

new_data_mentah.head()
# Out:
#     Age Embarked     Fare  Parch  PassengerId  Pclass     Sex  SibSp  \
# 0  22.0        S   7.2500      0            1       3    male      1
# 1  38.0        C  71.2833      0            2       1  female      1
# 2  26.0        S   7.9250      0            3       3  female      0
# 3  35.0        S  53.1000      0            4       1  female      1
# 4  35.0        S   8.0500      0            5       3    male      0
#
#    Survived  Family_Size
# 0       0.0            1
# 1       1.0            1
# 2       1.0            0
# 3       1.0            1
# 4       0.0            0

# %%
#tampilkan head uji

new_data_uji.head()
# Out:
#     Age Embarked     Fare  Parch  PassengerId  Pclass     Sex  SibSp  \
# 0  34.5        Q   7.8292      0          892       3    male      0
# 1  47.0        S   7.0000      0          893       3  female      1
# 2  62.0        Q   9.6875      0          894       2    male      0
# 3  27.0        S   8.6625      0          895       3    male      0
# 4  22.0        S  12.2875      1          896       3  female      1
#
#    Survived  Family_Size
# 0       NaN            0
# 1       NaN            1
# 2       NaN            0
# 3       NaN            0
# 4       NaN            2

# %%
#sekarang kita akan mengubah male : 0 dan female menjadi 1 pada kolom Sex. S = 1, C = 2, Q = 3 pada kolom embarked. Ubah kedua dataframe. 
#tampilkan head pada data mentah
#manfaatkan modul replace

new_data_mentah['Embarked'] = new_data_mentah['Embarked'].replace(to_replace=['S','C','Q'], value=[1,2,3])
new_data_mentah['Sex'] = new_data_mentah['Sex'].replace(to_replace=['male','female'], value=[0,1])

# %%
new_data_mentah.head()
# Out:
#     Age  Embarked     Fare  Parch  PassengerId  Pclass  Sex  SibSp  Survived  \
# 0  22.0         1   7.2500      0            1       3    0      1       0.0
# 1  38.0         2  71.2833      0            2       1    1      1       1.0
# 2  26.0         1   7.9250      0            3       3    1      0       1.0
# 3  35.0         1  53.1000      0            4       1    1      1       1.0
# 4  35.0         1   8.0500      0            5       3    0      0       0.0
#
#    Family_Size
# 0            1
# 1            1
# 2            0
# 3            1
# 4            0

# %% [markdown]
# Sekarang kita akan membagi data_mentah menjadi data training dan test

# %%
#pilih data yang akan menjadi fitur dan label. gunakan data_mentah karena kita akan membuat model
X = new_data_mentah[['Age','Embarked','Fare','Parch','PassengerId','Pclass','Sex','SibSp','Family_Size']]
y = new_data_mentah[['Survived']]

# %%
#import sklearn.feature_selection pada sel package/library aliaskan sebagai fs
#import module LogisticRegression dari sklearn.linear_model. taruh pada sel package/library

model_lr = LogisticRegression()
rfe = fs.RFE(model_lr)
rfe.fit(X,y)
print(f'Support = {rfe.support_}')
print(f'Ranking = {rfe.ranking_}')
# Out:
# Support = [False  True False False False  True  True  True False]
# Ranking = [4 1 5 3 6 1 1 1 2]

# %%
#sekarang kita ubah nilai X dengan mengikuti nilai kolom terbaik. urutan pada list ranking sesuai urutan pada saat inisiasi variabel X
# pilih ranking 1

X = new_data_mentah[['Embarked','Pclass','Sex','SibSp']]

# %%
'''import/tambahkan semua package/library pada sel paling atas(terkait library)
masukkan kedua kolom tersebut pada variabel yang bersesuaian.
kita bagi menjadi data training dan test dengan test_size = 0.2
'''

X_train, X_test, y_train, y_test = tts(X, y, test_size=0.2, random_state=36)

print(f'dimensi dari X_train : {len(X_train)}')
print(f'dimensi dari y_train : {len(y_train)}')
print(f'dimensi dari X_test : {len(X_test)}')
print(f'dimensi dari y_test : {len(y_test)}')
# Out:
# dimensi dari X_train : 712
# dimensi dari y_train : 712
# dimensi dari X_test : 179
# dimensi dari y_test : 179

# %% [markdown]
# 4. Data Processing

# %%
#training model
#langsung gunakan object logistic regression yang sudah dibuat sebelumnya

# fit the model with data
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Evaluasi
#kita buat variabel y_predict
#import modul metrics dari sklearn. Taruh pada sel package/library di awal
#test nilai AUC

y_pred = model_lr.predict(X_test)
auc = metrics.accuracy_score(y_test, y_pred)
print(f'Nilai AUC : {auc}')
# Out:
# Nilai AUC : 0.8324022346368715

# %% [markdown]
# Sekarang kita akan mencoba mengklasifikasikan data_uji kita

# %%
#buat sebuah variabel untuk menampung kolom dari data_uji. Ingat kolom yang dipilih harus sama dengan semua kolom pada saat memilih X
#lakukan prediksi dengan menggunakan variabel pada poin satu.
#masukkan variabel pada poin dua pada data uji kolom Survived
#tampilkan data_uji

new_data_uji['Embarked'] = new_data_uji['Embarked'].replace(to_replace=['S','C','Q'], value=[1,2,3])
new_data_uji['Sex'] = new_data_uji['Sex'].replace(to_replace=['male','female'], value=[0,1])

X_data_uji = new_data_uji[['Embarked','Pclass','Sex','SibSp']]
y_pred_data_uji = model_lr.predict(X_data_uji)
new_data_uji['Survived'] = y_pred_data_uji
new_data_uji
# Out:
#     Age  Embarked     Fare  Parch  PassengerId  Pclass  Sex  SibSp  Survived  \
# 0  34.5         3   7.8292      0          892       3    0      0       0.0
# 1  47.0         1   7.0000      0          893       3    1      1       1.0
# 2  62.0         3   9.6875      0          894       2    0      0       0.0
# 3  27.0         1   8.6625      0          895       3    0      0       0.0
# 4  22.0         1  12.2875      1          896       3    1      1       1.0
# 5  14.0         1   9.2250      0          897       3    0      0       0.0
# 6  30.0         3   7.6292      0          898       3    1      0       1.0
# 7  26.0         1  29.0000      1          899       2    0      1       0.0
# 8  18.0         2   7.2292      0          900       3    1      0       1.0
# 9  21.0         1  24.1500      0          901       3    0      2       0.0
#
#    Family_Size
# 0            0
# 1            1
# 2            0
# 3            0
# 4            2
# 5            0
# 6            0
# 7            2
# 8            0
# 9            2

# %%
#tuliskan hasil analisa kalian disini

# %% [markdown]
# Berdasarkan hasil uji prediksi dengan menggunakan model logistic linier, didapatkan hasil analisa sebagai berikut:
# - Dari preidiksi 10 data uji, terdapat 4 penumpang yang selamat
# - Dari prediksi data uji, penumpang yang selamat adalah yang berjenis kelamin perempuan dan yang memiliki Pclass dengan nilai 3
